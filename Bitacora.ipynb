# %% [markdown]
# # 📓 INICIO DEL PROYECTO: “Spotify del vocabulario en inglés”

# %% [markdown]
# ## 🧠 1. Idea general (resumen del proyecto)
#
# Crear una plataforma web para aprender inglés basada en vocabulario personalizado, donde el usuario:
#
# * Guarda palabras en “listas tipo playlists”
# * Estudia esas listas en una sola pantalla
# * Ve significado, pronunciación y ejemplos
# * Escucha audio de pronunciación
# * Aprende de forma visual, auditiva y por contexto
#
# 👉 Diferencia clave:
# En lugar de cursos rígidos, el usuario estudia *solo las palabras que le interesan*, organizadas como música en Spotify.
#
# ---

# %% [markdown]
# ## 🏗️ 2. Orden de construcción (de lo primero a lo último)
#
# ---

# %% [markdown]
# ### 🧱 FASE 1 — BASE DEL SISTEMA (fundación)
#
# #### 1. Definir estructura del proyecto
#
# Antes de programar:
#
# * Qué es una palabra
# * Qué es una lista (playlist)
# * Qué datos tendrá cada palabra
#
# Ejemplo de estructura:
#
# * palabra
# * traducción
# * IPA (pronunciación)
# * audio (opcional)
# * ejemplos (opcional)
#
# ---

# %% [markdown]
# #### 2. Base de datos (lo más importante al inicio)
#
# Diseñar tablas o colecciones:
#
# * Users
# * WordLists (playlists)
# * Words
# * ListItems (relación lista-palabra)
#
# 👉 Esto es el corazón del sistema.
#
# ---

# %% [markdown]
# #### 3. Backend básico
#
# Crear API que permita:
#
# * Crear listas
# * Agregar palabras a listas
# * Obtener listas del usuario
# * Obtener palabras de una lista
#
# ---

# %% [markdown]
# ### 🎨 FASE 2 — INTERFAZ BÁSICA (MVP visual)
#
# #### 4. Login / usuarios (simple)
#
# * Registro básico
# * Inicio de sesión
#
# ---

# %% [markdown]
# #### 5. Pantalla tipo “Spotify”
#
# Primera versión de UI:
#
# * Sidebar con listas
# * Panel central con palabras
# * Click en lista → muestra palabras
#
# 👉 Aquí ya empieza a sentirse como tu idea.
#
# ---

# %% [markdown]
# #### 6. CRUD de palabras
#
# * Crear palabra manualmente
# * Agregar a lista
# * Eliminar palabra
#
# ---

# %% [markdown]
# ### 🔊 FASE 3 — APRENDIZAJE REAL
#
# #### 7. Pronunciación básica
#
# Agregar:
#
# * Audio (Text-to-Speech)
# * IPA (fonética escrita)
#
# ✔ Esto ya hace útil el sistema
#
# ---

# %% [markdown]
# #### 8. Ejemplos de uso
#
# Primera versión simple:
#
# * Ejemplo fijo o guardado
# * o generado por API
#
# Ejemplo:
#
# > wake up → “I wake up at 7 AM”
#
# ---

# %% [markdown]
# ### 🧠 FASE 4 — INTELIGENCIA DEL SISTEMA
#
# #### 9. Generación automática de ejemplos
#
# * IA o backend que cree frases
# * Contexto según nivel del usuario
#
# ---

# %% [markdown]
# #### 10. Mejor organización de aprendizaje
#
# Agregar:
#
# * palabras favoritas
# * dificultad
# * etiquetas (travel, work, etc.)
#
# ---

# %% [markdown]
# ### 📚 FASE 5 — EXPERIENCIA AVANZADA
#
# #### 11. Repetición espaciada (tipo Anki)
#
# * palabras que se repiten según memoria
# * sistema de repaso inteligente
#
# ---

# %% [markdown]
# #### 12. Modo estudio
#
# Pantalla donde:
#
# * ves lista completa
# * avanzas palabra por palabra
# * escuchas audio
# * ves ejemplos
#
# ---

# %% [markdown]
# ### 🗣️ FASE 6 — FONÉTICA AVANZADA
#
# #### 13. Desglose fonético
#
# * separar palabra en fonemas
# * mostrar IPA interactivo
#
# ---

# %% [markdown]
# #### 14. Visual de pronunciación (visemas)
#
# * boca simplificada por sonidos
# * animación básica (no perfecta al inicio)
#
# 👉 Esto es lo más complejo, dejarlo al final.
#
# ---

# %% [markdown]
# ### 🚀 FASE 7 — OPTIMIZACIÓN Y ESCALA
#
# #### 15. Mejoras UX tipo Spotify
#
# * animaciones suaves
# * carga rápida
# * drag & drop de listas
# * búsqueda instantánea
#
# ---

# %% [markdown]
# #### 16. Personalización avanzada
#
# * listas recomendadas
# * palabras sugeridas
# * estadísticas de aprendizaje
#
# ---

# %% [markdown]
# ## 🧭 RESUMEN DEL ORDEN (muy importante)
#
# 1. Estructura de datos
# 2. Backend básico
# 3. UI tipo Spotify
# 4. CRUD de palabras/listas
# 5. Audio + IPA
# 6. Ejemplos
# 7. IA para ejemplos
# 8. repetición espaciada
# 9. modo estudio
# 10. fonética avanzada
# 11. visemas (boca)
# 12. optimización
#
# ---

# %% [markdown]
# ## ⚠️ CONSEJO CLAVE (muy importante)
#
# Tu proyecto NO es pequeño.
#
# Pero el error típico sería:
#
# > querer hacer fonética + IA + animación desde el día 1
#
# 💡 Lo correcto es:
# primero hacer una app simple que funcione, aunque sea “fea”, y luego mejorarla.
#
# ---

# %% [markdown]
# # 📋 Lista de funciones de tu sistema para aprender inglés

# %% [markdown]
# ## 🧠 1. Gestión de palabras (núcleo del sistema)
#
# * Crear palabras nuevas manualmente
# * Guardar palabra con:
#
#   * significado
#   * traducción
#   * IPA (pronunciación)
#   * audio de pronunciación
# * Editar palabras existentes
# * Eliminar palabras
# * Marcar palabras como favoritas
#
# ---

# %% [markdown]
# ## 📚 2. Listas tipo “playlists” (tipo Spotify)
#
# * Crear listas personalizadas de palabras
# * Nombrar listas (ej: “Trabajo”, “Viajes”, “Series”)
# * Agregar palabras a una o varias listas
# * Eliminar palabras de listas
# * Reordenar palabras dentro de una lista
# * Ver todas las listas del usuario en una sola pantalla
#
# ---

# %% [markdown]
# ## 🔍 3. Exploración y visualización
#
# * Ver todas las palabras de una lista en una sola vista
# * Vista tipo “reproductor” (palabra por palabra)
# * Búsqueda de palabras dentro del sistema
# * Filtrar palabras por lista, etiqueta o dificultad
#
# ---

# %% [markdown]
# ## 🔊 4. Pronunciación
#
# * Reproducir audio de la palabra (TTS o grabado)
# * Mostrar IPA (fonética internacional)
# * Separación fonética de la palabra (ej: /w eɪ k ʌ p/)
# * Repetir audio de pronunciación
#
# ---

# %% [markdown]
# ## 💬 5. Ejemplos de uso
#
# * Mostrar ejemplos de frases con la palabra
# * Generar ejemplos automáticamente (IA o API)
# * Guardar ejemplos favoritos
# * Ver traducción del ejemplo
#
# ---

# %% [markdown]
# ## 🧠 6. Aprendizaje inteligente
#
# * Marcar palabras como “aprendidas”
# * Marcar palabras como “difíciles”
# * Sistema de repaso (repetición espaciada tipo Anki)
# * Priorizar palabras que el usuario falla más
#
# ---

# %% [markdown]
# ## 🎯 7. Modo estudio
#
# * Modo pantalla completa de estudio
# * Mostrar palabra una por una
# * Mostrar:
#
#   * palabra
#   * audio
#   * significado
#   * ejemplo
# * Botones:
#
#   * “ya la sé”
#   * “no la sé”
#   * “repetir”
#
# ---

# %% [markdown]
# ## 🏷️ 8. Organización avanzada
#
# * Etiquetas personalizadas (tags)
# * Niveles de dificultad (básico, medio, avanzado)
# * Categorías temáticas (trabajo, viajes, etc.)
#
# ---

# %% [markdown]
# ## 🔎 9. Búsqueda y control
#
# * Buscar palabras globalmente
# * Buscar dentro de listas
# * Autocompletado al escribir palabras nuevas
#
# ---

# %% [markdown]
# ## 🔊 10. Sistema de audio
#
# * Text-to-speech automático
# * Opción de diferentes acentos (US / UK)
# * Repetición automática de palabras
# * Velocidad de audio ajustable
#
# ---

# %% [markdown]
# ## 🧬 11. Fonética avanzada (fase futura)
#
# * División visual de fonemas
# * Asociación de sonidos con símbolos IPA
# * Guía visual de pronunciación
#
# ---

# %% [markdown]
# ## 👄 12. Visual de pronunciación (avanzado)
#
# * Mostrar posición de la boca por sonido (visemas)
# * Animaciones simples de articulación
# * Relación fonema → movimiento de boca
#
# ---

# %% [markdown]
# ## 📊 13. Estadísticas del usuario
#
# * Palabras aprendidas
# * Palabras en progreso
# * Tiempo de estudio
# * Racha de estudio (streak)
#
# ---

# %% [markdown]
# ## ⚙️ 14. Sistema de usuario
#
# * Registro e inicio de sesión
# * Guardar progreso en la nube
# * Sincronización entre dispositivos
#
# ---

# %% [markdown]
# ## 🚀 15. Funciones avanzadas (futuro)
#
# * Generación de listas sugeridas por IA
# * Recomendación de palabras según nivel
# * Importar listas de otros usuarios
# * Compartir listas públicamente
#
# ---

# %% [markdown]
# ## 🧭 RESUMEN SIMPLE
#
# Tu app tendría 5 pilares principales:
#
# 1. 📚 Palabras
# 2. 📁 Listas tipo Spotify
# 3. 🔊 Pronunciación + audio
# 4. 🧠 Aprendizaje inteligente
# 5. 🎯 Modo estudio
#
# ---

# %% [markdown]
# # 📊 ¿Qué diagramas hacer para el proyecto? (GUIA)

# %% [markdown]
# Buena pregunta — aquí es donde muchos proyectos se “ordenan de verdad” o se vuelven un caos. Te voy a decir exactamente **qué diagramas usar, en qué orden, y para qué sirve cada uno**, aplicado a tu idea.
#
# ---

# %% [markdown]
# ## 🧭 1. Por dónde empezar (ANTES de diagramar)
#
# Antes de hacer diagramas, tienes que responder 3 cosas:

# %% [markdown]
# #### 🧠 A. Qué hace tu sistema (alto nivel)
#
# Ej:
#
# * Usuario crea palabras
# * Las organiza en listas
# * Las estudia
# * Escucha pronunciación
#
# ---

# %% [markdown]
# #### 👤 B. Quién usa el sistema
#
# * Usuario estudiante
#
# ---

# %% [markdown]
# #### 📦 C. Qué cosas existen
#
# * Palabra
# * Lista (playlist)
# * Usuario
# * Ejemplo
# * Audio
# * Progreso
#
# ---
#
# 👉 Con eso ya puedes diagramar sin perderte.
#
# ---

# %% [markdown]
# ## 🧩 2. Orden correcto de diagramas (MUY IMPORTANTE)
#
# Te recomiendo este orden exacto:
#
# ---

# %% [markdown]
# ### 1️⃣ 📊 Diagrama de casos de uso (Use Case Diagram)
#
# #### 🔥 PARA QUÉ SIRVE:

# %% [markdown]
# Ver qué puede hacer el usuario con tu sistema.
#
# #### 👇 En tu caso incluiría:
#
# * Crear cuenta
# * Crear lista
# * Agregar palabra a lista
# * Ver lista
# * Estudiar palabras
# * Escuchar pronunciación
# * Marcar palabra como aprendida
#
# 📌 Este es el diagrama MÁS importante para empezar.
#
# ---

# %% [markdown]
# ### 2️⃣ 🧱 Diagrama de entidades (modelo conceptual)
#
# #### 🔥 PARA QUÉ SIRVE:
#
# Definir qué “cosas existen” en tu sistema.
#
# #### En tu app:
#
# * User
# * Word
# * WordList
# * Example
# * Progress
#
# 📌 Esto todavía NO es base de datos, es conceptual.
#
# ---

# %% [markdown]
# ### 3️⃣ 🧠 Diagrama de relaciones (ERD - base de datos)
#
# #### 🔥 ESTE ES EL MÁS IMPORTANTE PARA PROGRAMAR
#
# Aquí defines cómo se conectan los datos:
#
# Ejemplo:
#
# * User → tiene muchas WordLists
# * WordList → tiene muchas Words
# * Word → puede estar en muchas listas
# * Word → tiene Examples
#
# ---

# %% [markdown]
# 📌 Esto ya se convierte en tu base de datos real.
#
# ---

# %% [markdown]
# ### 4️⃣ 🔄 Diagrama de flujo (Flowchart)
#
# #### 🔥 PARA QUÉ SIRVE:
#
# Ver cómo se mueve el usuario dentro de la app.
#
# Ejemplo:
#
# 1. Login
# 2. Ve listas
# 3. Entra a lista
# 4. Estudia palabra
# 5. Marca “la sé / no la sé”
#
# ---
#
# 📌 Esto te ayuda a diseñar la UX.
#
# ---

# %% [markdown]
# ### 5️⃣ 🖥️ Wireframes (diseño de pantallas)
#
# #### 🔥 PARA QUÉ SIRVE:
#
# Ver cómo se verá la app.
#
# Pantallas:
#
# * Home (listas tipo Spotify)
# * Vista de lista
# * Vista de palabra
# * Modo estudio
#
# 📌 Aquí ya estás diseñando la interfaz real.
#
# ---

# %% [markdown]
# ### 6️⃣ ⚙️ Diagrama de arquitectura (opcional pero útil)
#
# #### 🔥 PARA QUÉ SIRVE:
#
# Ver cómo se conecta todo técnicamente:
#
# * Frontend (React / Next.js)
# * Backend (API)
# * Base de datos
# * Servicio de audio / IA
#
# ---

# %% [markdown]
# ## 🧭 3. ORDEN RESUMIDO (lo que debes hacer)
#
# Te lo dejo súper claro:
#
# #### 🥇 1. Casos de uso (qué hace el usuario)
#
# #### 🥈 2. Modelo conceptual (qué existe)
#
# #### 🥉 3. ERD base de datos (cómo se conectan datos)
#
# #### 4. Flujos de usuario (cómo navega)
#
# #### 5. Wireframes (cómo se ve)
#
# #### 6. Arquitectura (cómo se programa)
#
# ---

# %% [markdown]
# ## 🧠 4. Qué diagrama usar para la base de datos
#
# 👉 RESPUESTA DIRECTA:
#
# El correcto es:
#
# ### 🧱 ERD (Entity Relationship Diagram)
#
# Este define:
#
# * tablas
# * relaciones
# * llaves primarias y foráneas
#
# ---

# %% [markdown]
# ### 📦 Ejemplo aplicado a tu proyecto:
#
# * users
# * word_lists
# * words
# * list_words (tabla puente)
# * examples
#
# ---

# %% [markdown]
# ## ⚠️ ERROR COMÚN QUE DEBES EVITAR
#
# No empieces directamente con la base de datos.
#
# Primero entiende:
#
# > “qué puede hacer el usuario”
#
# Si no haces eso:
# → tu base de datos termina mal diseñada
#
# ---

# %% [markdown]
# ## 🚀 Si quieres siguiente paso
#
# Puedo ayudarte a:
#
# 🔹 Hacerte el ERD completo de tu app (dibujado y explicado)
#
# 🔹 Diseñarte los casos de uso en formato visual
#
# 🔹 O darte un wireframe tipo Spotify para que lo copies en Figma
#
# Solo dime 👍

# %% [markdown]
# # Desarrollo de Casos de uso

# %% [markdown]
# ## 🙍‍♂️ Casos de Usos
#
# Se necesita responder a unas preguntas antes de empezar a dibujarel diagrama

# %% [markdown]
# ### 📌 Regla principal del diagrama de casos de uso
#
# > Un diagrama de casos de uso describe **qué puede hacer el usuario (o actor) con el sistema**, no cómo está implementado internamente.
# >
# > **Pregúntate siempre:**
# >
# > > "¿Esta acción la realiza o la solicita el usuario?"
# >
# > Si la respuesta es sí, probablemente es un caso de uso.
# >
# > Si la respuesta es no y describe algo interno del sistema, probablemente es una decisión técnica.
#
# ---
#
# #### Ejemplos
#
# ✅ Casos de uso
#
# * Buscar palabra
# * Crear lista
# * Guardar palabra
# * Escuchar pronunciación
# * Ver ejemplos
# * Iniciar sesión
#
# ---
#
# ❌ Decisiones técnicas
#
# * Consultar una API
# * Guardar en la base de datos
# * Generar audio con Text-to-Speech
# * Ejecutar una consulta SQL
# * Cachear palabras
#
# ---
#
# También te dejaría una versión aún más corta para ponerla como encabezado permanente:
#
# > **Casos de uso = Qué hace el usuario.**
# >
# > **Arquitectura técnica = Cómo lo hace el sistema.**
#
# Si durante el análisis te surge una idea y dudas dónde ponerla, prueba esta pregunta:
#
# > **¿El usuario puede hacer clic en esto, solicitarlo o verlo como una función?**
# >
# > * Sí → Caso de uso.
# > * No → Probablemente diseño técnico o arquitectura.
#
# Esa regla te evitará el 90% de las confusiones mientras diseñas tu aplicación.

# %% [markdown]
# ### 1️⃣ ¿Quién interactúa con el sistema? (Actores)
#
# Por ahora parece que tienes:
#
# - 👤 Visitante
# - 👤 Usuario registrado
#
# Más adelante podrías tener:
#
# - 👨‍💼 Administrador
# - 🤖 Servicio de IA
# - 🔊 Servicio de audio
#
# ---

# %% [markdown]
# ### 2️⃣ ¿Qué objetivos tiene el usuario?
#
# No pienses en botones o pantallas.
#
# Piensa:
#
#     ¿Qué quiere lograr el usuario?
#
# Por ejemplo:
#
# - Crear una lista de palabras
# - Agregar palabras a una lista
# - Estudiar palabras
# - Escuchar pronunciación
# - Ver ejemplos
# - Buscar palabras
# - Marcar palabras aprendidas
#
# ---

# %% [markdown]
# ### 3️⃣ ¿Qué puede hacer el usuario desde que entra hasta que sale?
#
# Imagina este escenario:
#
#     "Luis entra a la aplicación para estudiar inglés"
#
# Ahora responde:
#
# - ¿Qué hace primero? (
#     - Busca palabras en el sistema
#     - Accede a una lista de palabras existente)
# - ¿Qué hace después? (
#     - Estudiar palabras
#     - Agregar palabras a una lista
#     - Organizar listas
# )
# - ¿Qué puede hacer mientras estudia? (
#     - Ver pronunciación fonética (IPA)
#     - Escuchar pronunciación
#     - Ver posición de la boca para pronunciar
#     - Ver ejemplos de uso
# )
# - ¿Qué puede guardar? (
#     - Crear listas de palabras personalizadas
#     - Guardar palabras dentro de una lista
#     - Guardar cambios realizados en sus listas
# )
# - ¿Qué puede modificar? (
#     - Editar lista
#     - Reordenar palabras
#     - Agregar palabra a lista
#     - Eliminar palabra de lista
# )
# - ¿Qué puede eliminar? (
#     - Eliminar palabras de una lista
#     - Eliminar listas completas
# )
#
# ---

# %% [markdown]
# ### Preguntas que te recomiendo responder
#
# Vamos una por una.
#
# Sobre usuarios
# - ¿Habrá registro de usuarios? (si)
# - ¿Habrá inicio de sesión? (si)
# - ¿Se podrá usar sin cuenta? (si)
#
# ---

# %% [markdown]
# ### Actores
#
# 👤 Visitante
#
# El visitante puede:
#
# - Buscar palabras
# - Ver significado
# - Ver IPA
# - Escuchar pronunciación
# - Ver ejemplos
# - Ver posición de la boca
#
# Es decir, puede consumir contenido.
#
# ---
#
# 👤 Usuario registrado
#
# El usuario registrado puede:
#
# - Crear listas
# - Guardar palabras
# - Modificar listas
# - Eliminar listas
# - Guardar progreso
# - Sincronizar entre dispositivos
#
# Es decir, puede **guardar** información personal.
#
# ---

# %% [markdown]
# ### Sobre listas
#
# * ¿Un usuario puede crear varias listas?
#
# >Si, sin limites de listas, ya que ocupa poco espacio en base de datos, tampoco limite de palabras en cada lista ✅
#
# >paginación ✅ carga por bloques Ejemplo: Mostrar 50 palabras y cargar más al bajar.
#
# * ¿Puede editar el nombre de una lista? (Si)
# * ¿Puede eliminar listas? (Si)
# * ¿Puede compartir listas?
#
# >Si, ✅ Compartir mediante enlace público. Ya que es menos complejo.
#
# ---

# %% [markdown]
# ### Sobre palabras
#
# * ¿Las palabras se crean manualmente?
#
#         No el usuario no crea palabras, solo las consulta
#
# * ¿Se buscan en un diccionario?
#
# >El usuario busca una palabra mediante una barra de búsqueda. El sistema consulta el catálogo de palabras y muestra información relacionada.
#
# >pantalla dividida, izquierda lista de palabras, derecha contenido multimedia de la palabra elegida. [Más info](#interfaz-destino)
#
# * ¿Se pueden editar?
# >El usuario no puede modificar la información de una palabra. Solo puede gestionar las listas donde guarda palabras.
#
# * ¿Se pueden eliminar?
# >El usuario puede eliminar palabras de sus listas personales, pero no del catálogo general de palabras.
#
# ---

# %% [markdown]
# ### Sobre aprendizaje
#
# * ¿Cómo estudia una palabra?
# >El usuario estudia una palabra consultando su información y material de apoyo proporcionado por el sistema.
# * ¿Solo la ve?
# >Puede ver la palabra, su significado, pronunciación fonética (IPA) y la posición de la boca para pronunciarla correctamente.
# * ¿Escucha audio?
# >Si, lo escucha las veces que sea.
# * ¿Ve ejemplos?
# >Puede consultar ejemplos de uso de la palabra en contexto.
# * ¿Marca si la aprendió?
# >Sí. El usuario puede marcar una palabra como aprendida para indicar que ya no necesita seguir estudiándola.
# ---

# %% [markdown]
# ### Sobre progreso
#
# * ¿Se guarda el progreso?
# >Sí. El sistema guarda el progreso de aprendizaje del usuario dentro de sus listas de palabras.
# * ¿Se muestran estadísticas?
# >Sí. El usuario puede consultar estadísticas básicas sobre su progreso, como palabras aprendidas, pendientes y porcentaje completado.
# * ¿Habrá rachas de estudio?
# >No en la primera versión. Esta funcionalidad podría añadirse en futuras actualizaciones.
#
# ---

# %% [markdown]
# ## Resultado esperado
#
# ### 👤 Visitante
#
# #### Acceso
#
# * Registrarse
# * Iniciar sesión
#
# ---

# %% [markdown]
# #### Consulta de vocabulario
#
# * Buscar palabras
# * Ver significado
# * Ver pronunciación fonética (IPA)
# * Escuchar pronunciación
# * Ver ejemplos de uso
# * Ver posición de la boca para la pronunciación
#
# ---

# %% [markdown]
# ### 👤 Usuario registrado
#
# Puede realizar todas las acciones de consulta de vocabulario disponibles para un visitante y además:
#
# #### Gestión de cuenta
#
# * Modificar cuenta
# * Eliminar cuenta
# * Cerrar sesión
# * Recuperar contraseña
#
# #### Gestión de listas
#
# * Crear lista
# * Ver lista
# * Editar lista
# * Eliminar lista
# * Compartir lista mediante enlace público
# * Agregar palabra a una lista
# * Eliminar palabra de una lista
# * Reordenar palabras dentro de una lista

# %% [markdown]
# #### Aprendizaje
#
# * Estudiar lista de palabras
# * Marcar palabra como aprendida
#
# #### Seguimiento
#
# * Ver progreso de aprendizaje
# * Ver estadísticas básicas
#
# ---

# %% [markdown]
# ## Lista futura
#
# * Se podra poner publica cualquier lista creada y aparecera en el resultado de busqueda de cualquier usuario registrado y podran copiar la lista para su uso
# * Se manejara rachas de estudio

# %% [markdown]
# Y eso ya es prácticamente el contenido de tu primer diagrama de casos de uso.
#
# Mi recomendación es que respondas las preguntas de **listas**, **palabras** y **aprendizaje** primero (aunque sea de forma breve), y con eso te ayudo a construir el diagrama completo paso a paso.

# %% [markdown]
# ## Diagrama
#
# ![CasosDeUsoVocabulario (1).jpg](<attachment:CasosDeUsoVocabulario (1).jpg>)

# %% [markdown]
# # Diagrama de entidades (ERD) 🕸

# %% [markdown]
# ## Preguntas para empezar ❓

# %% [markdown]
# **¿Qué información necesita guardar el sistema para que esos casos de uso funcionen?**

# %% [markdown]
# - Usuario
# - Palabra
# - Lista
# - Progreso
# - ListaPalabra

# %% [markdown]
# ## Usuario
# - id
# - nombre
# - apellido
# - email
# - contraseña
# - fecha_registro

# %% [markdown]
# ## Palabra
# - id
# - nombre
# - significado
# - tipo_palabra (sustantivo, verbo etc.)
# - ipa
# - audio
# - ejemplos

# %% [markdown]
# ## Lista
#
# - id
# - nombre
# - usuario_id
# - fecha_creacion

# %% [markdown]
# ## SimboloFonetico
#
# - id
# - simbolo
# - imagen

# %% [markdown]
# ## ListaPalabra (Entidad Intermedia)
#
# - lista_id
# - palabra_id
# - aprendida
# - fecha_agregada (palabra agregada a la lista, su fecha)
# - ultimo_repaso

# %% [markdown]
# ## Diagrama ERD 🕸

# %% [markdown]
# ![Diagrama de entidades.jpg](<attachment:Diagrama de entidades.jpg>)

# %% [markdown]
# # Diagrama de flujo (Flowchart)

# %% [markdown]
# ![Flowchart.jpg](attachment:Flowchart.jpg)

# %% [markdown]
# # WireFrames 💻

# %% [markdown]
# Paleta de colores

# %% [markdown]
# #355B92
# #FFFCCB
# #FFFFFF
# #429FAA

# %% [markdown]
# ![AdobeColor-Mi tema de color.jpeg](<attachment:AdobeColor-Mi tema de color.jpeg>)

# %% [markdown]
# **Boceto inicial**

# %% [markdown]
# ![DiseñoBoceto.png](attachment:DiseñoBoceto.png)

# %% [markdown]
# Esta es la pagina principal, en donde el visitante sin registrarse podrá ver el resultado de palabras que busque y como se vera el body principal para empezar a estudiar alguna palabra, como el significado, la escritura fonetica IPA el boton de pronunciación, imagenes de la forma de la boca al pronuciar y algun ejemplo de como utilizar la palabra.

# %% [markdown]
# ![1-inicio.jpg](attachment:1-inicio.jpg)

# %% [markdown]
# Así es como se ve cuando el usuario ya se encuentra registrado en el sistema; podrá ver el boton de listas y un boton para informacion adicional, omo perfil y cerrar sesión. También contara con un boton para agregar la palabra a alguna lista ya creada.

# %% [markdown]
# ![2-iniciousuarioregistrado.jpg](attachment:2-iniciousuarioregistrado.jpg)

# %% [markdown]
# Así se ve la sección de Mis listas, puede observar sus listas ya creadas y tambien puede crear nuevas listas.

# %% [markdown]
# ![3-crearlista.jpg](attachment:3-crearlista.jpg)

# %% [markdown]
# Forma que se ve para borrar listas

# %% [markdown]
# ![3.1-crearlista.jpg](attachment:3.1-crearlista.jpg)

# %% [markdown]
# Así se ve cuando esta dentro de una lista, el usuario observara el listado de sus palabras, puee ver la informacion de la palara para empezar a estudiar; tendra una barra de porcentaje de aprendido de la lista en general; tendar un botón el cual es para marcar si la palabra ya se aprendio o no.

# %% [markdown]
# ![4-lista.jpg](attachment:4-lista.jpg)

# %% [markdown]
# Así se ve para borrar palabras en la lista

# %% [markdown]
# ![4.1-lista.jpg](attachment:4.1-lista.jpg)

# %% [markdown]
# ![5-registro.jpg](attachment:5-registro.jpg)

# %% [markdown]
# ![6-iniciodesesion.jpg](attachment:6-iniciodesesion.jpg)

# %% [markdown]
# # Design System.

# %% [markdown]
# 🎨 Colores
#
# 🔤 Tipografía
#
# 📏 Espaciados
#
# 🔘 Botones
#
# ⌨ Inputs
#
# 🃏 Tarjetas (Cards)
#
# 🔍 Barra de búsqueda
#
# 🖼 Iconos
#
# 📱 Header
#
# 📄 Footer

# %% [markdown]
# # Tecnologias

# %% [markdown]
# **Tabla**
#
# | Categoría                    | Tecnología                      | ¿Por qué?                                                                     |
# | ---------------------------- | ------------------------------- | ----------------------------------------------------------------------------- |
# | **Frontend**                 | **React**                       | Muy demandado en el mercado laboral y excelente para interfaces web modernas. |
# | **Backend**                  | **FastAPI**                     | Rápido, moderno y aprovecha tus conocimientos de Python.                      |
# | **Base de datos**            | **PostgreSQL**                  | Ideal para datos con muchas relaciones, como los de Fonoflow.                 |
# | **Control de versiones**     | **Git + GitHub**                | Estándar de la industria para gestionar código y colaborar.                   |
# | **Diseño UI/UX**             | **Figma**                       | Herramienta líder para diseñar interfaces y prototipos.                       |
# | **Editor de código**         | **VS Code**                     | Ligero, potente y ampliamente utilizado.                                      |
# | **Despliegue Frontend**      | **Vercel**                      | Muy fácil de publicar aplicaciones React.                                     |
# | **Despliegue Backend**       | **Render**                      | Hospeda FastAPI fácilmente y se integra con GitHub.                           |
# | **Base de datos en la nube** | **Neon**                        | Servicio PostgreSQL administrado con plan gratuito.                           |
# | **Arquitectura**             | **Cliente–Servidor + API REST** | Arquitectura estándar para aplicaciones web modernas.                         |
#
# En una sola línea, el stack quedaría así:
#
# > **React + FastAPI + PostgreSQL + Git/GitHub + Figma + VS Code + Vercel + Render + Neon.**
#
# ---

# %% [markdown]
# # Ideas
#
# Tu idea es bastante buena porque estás pensando en **reutilizar recursos** en lugar de almacenar información repetida.
#
# La parte de las imágenes me gusta especialmente.
#
# ---
#
# ## Integración de imagenes, audio,
#
# ### 👄 Imágenes de posición de boca
#
# Tu idea sería algo así:
#
# ```text
# wake up
# ↓
# /w eɪ k ʌ p/
# ↓
# [w] → imagen_01
# [eɪ] → imagen_02
# [k] → imagen_03
# [ʌ] → imagen_04
# [p] → imagen_05
# ```
#
# Y luego la interfaz muestra:
#
# 👄 → 👄 → 👄 → 👄 → 👄
#
# según los fonemas.
#
# ---
#
# #### Ventaja enorme
#
# No necesitas una imagen por palabra.
#
# Necesitas una imagen por fonema.
#
# Por ejemplo, el inglés tiene alrededor de:
#
# * ~24 consonantes
# * ~20 vocales
#
# Dependiendo del sistema fonético.
#
# En la práctica podrías tener:
#
# * 30–50 imágenes
#
# Y reutilizarlas para miles de palabras.
#
# ---
#
# #### Espacio ocupado
#
# Supongamos:
#
# * 50 imágenes
# * 100 KB cada una
#
# Eso son:
#
# ```text
# 50 × 100 KB = 5 MB
# ```
#
# Prácticamente nada.
#
# ---
#
# ### 🔊 Sobre el audio
#
# Aquí sí hay varias opciones.
#
# ---
#
# #### Opción 1: Grabar cada palabra
#
# Ejemplo:
#
# ```text
# wake-up.mp3
# journey.mp3
# effort.mp3
# ```
#
# ###### Problema
#
# 10,000 palabras.
#
# Aunque cada audio pesara solo 20 KB:
#
# ```text
# 10,000 × 20 KB
# ≈ 200 MB
# ```
#
# Y en la realidad probablemente sería más.
#
# ---
#
# ###### Ventajas
#
# * Sonido natural
# * Control total
#
# ###### Desventajas
#
# * Muchísimo trabajo
# * Mucho almacenamiento
# * Difícil de mantener
#
# ---
#
# #### Opción 2: Text-to-Speech (TTS)
#
# Lo que usan muchas aplicaciones.
#
# Tú guardas:
#
# ```text
# wake up
# ```
#
# Y cuando el usuario presiona reproducir:
#
# un motor genera la voz.
#
# ---
#
# ###### Ventajas
#
# * No almacenas audios
# * Tamaño casi cero
# * Fácil de escalar
#
# ---
#
# ###### Desventajas
#
# * Dependes de un servicio
# * Algunas voces suenan robóticas
#
# ---
#
# #### Opción 3: Usar la voz del navegador
#
# Esta es muy interesante para un MVP.
#
# Los navegadores modernos tienen:
#
# ```javascript
# speechSynthesis
# ```
#
# Por ejemplo:
#
# ```javascript
# speechSynthesis.speak(
#   new SpeechSynthesisUtterance("wake up")
# )
# ```
#
# ---
#
# ###### Ventajas
#
# * Gratis
# * Sin APIs
# * Sin almacenar audios
# * Sin costos mensuales
#
# ---
#
# ###### Desventajas
#
# * La calidad depende del dispositivo
# * Algunas voces son mejores que otras
#
# ---
#
# ### ¿Y las APIs?
#
# Existen muchas.
#
# Por ejemplo:
#
# * Servicios de voz de grandes proveedores tecnológicos
# * APIs especializadas de síntesis de voz
#
# Generalmente cobran por cantidad de caracteres generados.
#
# ---
#
# #### Mi recomendación para tu proyecto
#
# Si yo estuviera construyendo tu MVP:
#
# ###### Fase 1
#
# ✅ Texto
#
# ✅ IPA
#
# ✅ Imágenes de boca por fonema
#
# ✅ Audio usando la voz integrada del navegador (`speechSynthesis`)
#
# Costo:
#
# 💰 $0
#
# ---
#
# ###### Fase 2
#
# Cuando tengas usuarios:
#
# ✅ Migrar a una API de voz de mayor calidad si realmente lo necesitas.
#
# ---
#
# ### Otra idea que me parece muy interesante
#
# Podrías construir algo así:
#
# ```text
# wake up
# ↓
# /weɪk ʌp/
# ↓
# [w] [eɪ] [k] [ʌ] [p]
# ↓
# 👄  👄  👄  👄  👄
# ↓
# 🔊 Reproducir palabra
# ```
#
# Y cuando el usuario toca un fonema:
#
# ```text
# [w]
# ↓
# 👄 imagen
# ↓
# 🔊 sonido aislado del fonema
# ```
#
# Eso sí sería una característica bastante diferenciadora respecto a muchas apps de vocabulario, porque enseñaría la pronunciación desde los sonidos individuales y no solo desde la palabra completa.

# %% [markdown]
# ## Interfaz de palabras
#
# <a id="interfaz-destino"></a>
#
# Preguntas:
#
# > ¿qué me recomiendas implementar que cuando escoja una lista pueda ver la información principal y que aún pueda ver o tener acceso fácilmente a la lista de palabras?
#
# Yo haría algo parecido a Spotify.
#
# ---
#
# ### Vista dividida
#
# ##### Panel izquierdo
#
# ```text
# Mis listas
#
# 📁 Viajes
# 📁 Trabajo
# 📁 Phrasal Verbs
# 📁 Clima
# ```
#
# Siempre visible.
#
# ---
#
# ##### Panel principal
#
# Cuando selecciona:
#
# ```text
# 📁 Phrasal Verbs
# ```
#
# Ve:
#
# ```text
# wake up
# take off
# look after
# run into
# ```
#
# ---
#
# ##### Al seleccionar una palabra
#
# El panel principal cambia:
#
# ```text
# wake up
#
# IPA: /weɪk ʌp/
#
# 🔊 Audio
#
# 👄 Posición de boca
#
# 💬 Ejemplos
#
# ⭐ Guardar
# ```
#
# Pero la lista sigue visible a la izquierda.
#
# Eso permite navegar rápido.
#
# ---

# %% [markdown]
# ## Progreso de aprendizaje de palabras

# %% [markdown]
# El progreso de aprendizaje será global para cada usuario. Si una palabra se marca como aprendida, aparecerá como aprendida en cualquier lista y también en el buscador.
#
# Por el momento el progreso de la palabra se mantiene dentro de la lista del usuario. Es decir si marca la palabra como aprendida dentro de su lista, solo aparecera aprendida en su lista, y si la ve en el buscador general aparecera normal (sin aprender)
#
# ---

# %% [markdown]
# ## Crear un ancla / link en markdown
#
# 1. Crea un identificador (ancla) en la celda de destinoVe a la celda de texto que quieres que sea tu destino. Haz doble clic en ella para editarla (debe ser de tipo Markdown) y agrega un ID al principio usando una etiqueta HTML
#
# ```html
# html<a id="mi-cuadro-destino"></a>
# ```
#
# 2. Crea el enlace en la celda de origenEn la celda donde quieres colocar el link (también en formato Markdown), escribe el enlace utilizando el símbolo de gato # seguido del ID que creaste:
#
# ```html
# [Ir al cuadro de destino](#mi-cuadro-destino)
# ```

# %% [markdown]
# ## Ideas Futuras

# %% [markdown]
# ### Listas publicas
#
# El usuario registrado podrá colocar sus listas publicas para que otros usuarios las puedan copiar y estudiarlas.
# Es como buscar una palabra mas pero con listas creadas por usuarios.

# %% [markdown]
# ## Orden de las palabras en las listas

# %% [markdown]
# Me alegra que estés haciendo este tipo de preguntas, porque aquí es donde se diferencia un **MVP** de un proyecto que intenta hacerlo todo desde el principio.
#
# **Mi recomendación: déjalo para una segunda actualización.**
#
# No porque sea imposible, sino porque **añade bastante complejidad** para un beneficio relativamente pequeño al inicio.
#
# ---
#
# **¿Qué tan difícil es?**
#
# Depende de cómo quieras que funcione.
#
# ### Opción 1: Botones "Subir" y "Bajar" ⭐
#
# ```
# wake up      ↑ ↓
# take off     ↑ ↓
# look after   ↑ ↓
# ```
#
# Dificultad: **3/10**
#
# Solo necesitas guardar un atributo más en `ListaPalabra`:
#
# ```text
# ListaPalabra
# ------------
# lista_id
# palabra_id
# orden
# aprendida
# fecha_agregada
# ultimo_repaso
# ```
#
# Y cuando el usuario pulsa ↑ o ↓, intercambias el valor de `orden` entre dos palabras.
#
# Es bastante sencillo.
#
# ---
#
# ### Opción 2: Arrastrar y soltar (Drag & Drop)
#
# Como Spotify o Trello.
#
# ```
# ☰ wake up
# ☰ take off
# ☰ look after
# ```
#
# El usuario arrastra las palabras.
#
# Dificultad: **7/10**
#
# Necesitas:
#
# * Detectar el arrastre.
# * Actualizar el orden visual.
# * Guardar el nuevo orden en la base de datos.
# * Manejar casos donde el usuario mueve una palabra del principio al final.
#
# No es extremadamente difícil, pero sí requiere más trabajo.
#
# ---
#
# **¿Vale la pena en el MVP?**
#
# Yo diría que **no**.
#
# Pregúntate:
#
# > ¿Mi aplicación deja de ser útil si las palabras siempre aparecen en el orden en que fueron agregadas?
#
# La respuesta es:
#
# **No.**
#
# Ya puedes estudiar.
#
# Ya puedes buscar.
#
# Ya puedes crear listas.
#
# Ya puedes compartir listas.
#
# El producto sigue siendo útil.
#
# ---
#
# **Lo que yo haría**
#
# **Versión 1**
#
# Permitiría:
#
# * ✅ Crear listas.
# * ✅ Eliminar listas.
# * ✅ Agregar palabras.
# * ✅ Eliminar palabras.
# * ✅ Las palabras aparecen en el orden de creación (`fecha_agregada`).
#
# ---
#
# **Versión 1.5**
#
# Agregaría:
#
# ```
# ↑
# ↓
# ```
#
# para mover palabras.
#
# ---
#
# **Versión 2**
#
# Implementaría Drag & Drop.
#
# ---
#
# **Incluso modificaría tus casos de uso**
#
# En lugar de poner:
#
# ```
# Reordenar palabras
# ```
#
# Lo movería al backlog.
#
# ---
#
# **Mi backlog sería algo así**
#
# **MVP**
#
# * Buscar palabras
# * Crear listas
# * Agregar palabras
# * Eliminar palabras
# * Marcar aprendidas
# * Compartir listas
# * Estadísticas básicas
#
# ---
#
# **Versión 2**
#
# * Reordenar palabras
# * Drag & Drop
# * Listas públicas
# * Comentarios
# * IA para generar ejemplos
# * Repaso inteligente
#
# ---
#
# **Hay otra razón para dejarlo después**
#
# He visto que desde que empezaste este proyecto tienes una forma de pensar muy buena: primero diseñas el sistema y luego programas.
#
# Eso hace que sea fácil caer en la tentación de decir:
#
# > "Ya que estoy aquí, también le agrego..."
#
# Y de repente el MVP tiene 80 funcionalidades.
#
# Mi consejo es que tu primera versión tenga un objetivo muy claro:
#
# > **Que un usuario pueda crear una cuenta, buscar palabras, guardarlas en listas y estudiarlas.**
#
# Si consigues eso, ya tendrás una aplicación funcional y útil. Después podrás añadir mejoras como el reordenamiento de palabras, y además lo harás sobre una base estable, sin haber retrasado meses el lanzamiento de tu proyecto.
